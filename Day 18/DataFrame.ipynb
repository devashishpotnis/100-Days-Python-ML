# %%
import pandas as pd

# %%
#Creating a DataFrame (Manually using Dictionary)
data = {
    "Name": ["Devashish", "Rahul", "Amit"],
    "Age": [22, 23, 24],
    "City": ["Pune", "Mumbai", "Delhi"]
}

df = pd.DataFrame(data)

print("\nDataFrame:")
print(df)
# Out:
# DataFrame:
#         Name  Age    City
# 0  Devashish   22    Pune
# 1      Rahul   23  Mumbai
# 2       Amit   24   Delhi
