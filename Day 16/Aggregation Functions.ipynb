# %%
import numpy as np

# %%
arr = np.array([[1, 2, 3],
                [4, 5, 6]])

# %%
#🔹 sum()
np.sum(arr)
# Out:
# np.int64(21)

# %%
#mean()
np.mean(arr)
# Out:
# np.float64(3.5)

# %%
#min() and max()
np.min(arr)
np.max(arr)
# Out:
# np.int64(6)

# %%
#std() (Standard Deviation)

np.std(arr)
# Out:
# np.float64(1.707825127659933)
